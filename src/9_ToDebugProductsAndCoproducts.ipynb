# %%
using Catlab

# %% [markdown]
# # 1. The Reflexive Graph Schema

# %% [markdown]
# ### To use the visualization function define in Catlab.jl, we use the pre-built graph schema of "SchReflexiveGraph" in Catlab.jl. The SchGraph schema is:

# %%
to_graphviz(SchReflexiveGraph)
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "neato", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "V")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "E")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "src")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "tgt")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "refl"))], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:margin => "0", :shape => "ellipse"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())

# %% [markdown]
# # Graphs have the built-in ACSet ReflexiveGraph

# %%
const 𝒞 = ACSetCategory(CSetCat(ReflexiveGraph()))
# Out:
# ACSetCategory(CSetCat(ReflexiveGraph), Dict{Symbol, Type}(:Cat => ConcreteCategory, :ACSHom => ACSetTransformation, :Hom => FinFunction, :Op => Union{}, :Sym => Symbol, :AttrType => Union{}, :Ob => FinSetInt, :Attr => Union{}, :ACS => ACSet, :Hetero => ConcreteHeteroMorphism…))

# %%
T = terminal[𝒞]()
# Out:
# ACSetLimit(Multispan{ReflexiveGraph, ACSetTransformation, Any, Vector{ACSetTransformation}, Vector{Any}}(ReflexiveGraph:
#   V = 1:1
#   E = 1:1
#   src : E → V = [1]
#   tgt : E → V = [1]
#   refl : V → E = [1], ACSetTransformation[], Any[]), (V = TerminalLimit{FinSetInt, FinFunction}(FinSet(1)), E = TerminalLimit{FinSetInt, FinFunction}(FinSet(1))), FreeDiagram(EmptyDiagram{ACSet, StaticArraysCore.SVector{0, ACSet}}(ACSet[]), Dict{Symbol, Type}(:Ob => ACSet, :FSet => FinSet, :Hom => Union{}, :V => Int64, :E => Int64)))

# %%
apex(T)
# Out:
# ReflexiveGraph {V:1, E:1}
# ┌───┬──────┐
# │ V │ refl │
# ├───┼──────┤
# │ 1 │    1 │
# └───┴──────┘
# ┌───┬─────┬─────┐
# │ E │ src │ tgt │
# ├───┼─────┼─────┤
# │ 1 │   1 │   1 │
# └───┴─────┴─────┘

# %%
to_graphviz(apex(T))
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => ""))], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0.05", :margin => "0", :shape => "point", :width => "0.05"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:arrowsize => "0.5"))

# %%
I = initial[𝒞]()
# Out:
# ACSetColimit(Multicospan{ReflexiveGraph, ACSetTransformation, Any, Vector{ACSetTransformation}, Vector{Any}}(ReflexiveGraph:
#   V = 1:0
#   E = 1:0
#   src : E → V = Int64[]
#   tgt : E → V = Int64[]
#   refl : V → E = Int64[], ACSetTransformation[], Any[]), (V = InitialColimit{FinSetInt, FinFunction}(FinSet(0)), E = InitialColimit{FinSetInt, FinFunction}(FinSet(0))), FreeDiagram(EmptyDiagram{ACSet, StaticArraysCore.SVector{0, ACSet}}(ACSet[]), Dict{Symbol, Type}(:Ob => ACSet, :FSet => FinSet, :Hom => Union{}, :V => Int64, :E => Int64)))

# %%
to_graphviz(apex(I))
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0.05", :margin => "0", :shape => "point", :width => "0.05"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:arrowsize => "0.5"))

# %% [markdown]
# # 2. Define Graph instances

# %% [markdown]
# ## 2.1 Graph instance A, note it is a functor G: SchGraph -> FinSet

# %%
g_A = @acset ReflexiveGraph begin
    V = 3
    E = 5
    src = [1, 2, 1, 2, 3]
    tgt = [2, 3, 1, 2, 3]
    refl = [3, 4, 5]
end
# Out:
# ReflexiveGraph {V:3, E:5}
# ┌───┬──────┐
# │ V │ refl │
# ├───┼──────┤
# │ 1 │    3 │
# │ 2 │    4 │
# │ 3 │    5 │
# └───┴──────┘
# ┌───┬─────┬─────┐
# │ E │ src │ tgt │
# ├───┼─────┼─────┤
# │ 1 │   1 │   2 │
# │ 2 │   2 │   3 │
# │ 3 │   1 │   1 │
# │ 4 │   2 │   2 │
# │ 5 │   3 │   3 │
# └───┴─────┴─────┘

# %% [markdown]
# ## Recall our graph A

# %%
to_graphviz(g_A; node_labels=true, edge_labels=true)
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "1")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "2")), Catlab.Graphics.Graphviz.Node("n3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "3")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "1")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "2"))], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0.05", :margin => "0", :shape => "circle", :width => "0.05"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:arrowsize => "0.5"))

# %% [markdown]
# ## Now we define a graph with a two vertices, and a single edge betweenst them (plus the reflexive edges)

# %%
g_connectedPair = @acset ReflexiveGraph begin
    V = 2
    E = 3
    src = [1, 1, 2]
    tgt = [2, 1, 2]
end
# Out:
# ReflexiveGraph {V:2, E:3}
# ┌───┬──────┐
# │ V │ refl │
# ├───┼──────┤
# │ 1 │    0 │
# │ 2 │    0 │
# └───┴──────┘
# ┌───┬─────┬─────┐
# │ E │ src │ tgt │
# ├───┼─────┼─────┤
# │ 1 │   1 │   2 │
# │ 2 │   1 │   1 │
# │ 3 │   2 │   2 │
# └───┴─────┴─────┘

# %%
to_graphviz(g_connectedPair; node_labels=true, edge_labels=true)
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "1")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "2")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "1")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "2")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "3"))], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0.05", :margin => "0", :shape => "circle", :width => "0.05"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:arrowsize => "0.5"))

# %%
## Now we define a graph with three vertices, and two edges end-to-end (plus the reflexive edges)

# %%
g_endToEnd = @acset ReflexiveGraph begin
    V = 3
    E = 5
    src = [1, 2, 1, 2, 3]
    tgt = [2, 3, 1, 2, 3]
end
# Out:
# ReflexiveGraph {V:3, E:5}
# ┌───┬──────┐
# │ V │ refl │
# ├───┼──────┤
# │ 1 │    0 │
# │ 2 │    0 │
# │ 3 │    0 │
# └───┴──────┘
# ┌───┬─────┬─────┐
# │ E │ src │ tgt │
# ├───┼─────┼─────┤
# │ 1 │   1 │   2 │
# │ 2 │   2 │   3 │
# │ 3 │   1 │   1 │
# │ 4 │   2 │   2 │
# │ 5 │   3 │   3 │
# └───┴─────┴─────┘

# %%
to_graphviz(g_endToEnd)
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n3", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0.05", :margin => "0", :shape => "point", :width => "0.05"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:arrowsize => "0.5"))

# %%
g_singleVertex = @acset ReflexiveGraph begin
    V = 1
    E = 1
    src = [1]
    tgt = [1]
end
# Out:
# ReflexiveGraph {V:1, E:1}
# ┌───┬──────┐
# │ V │ refl │
# ├───┼──────┤
# │ 1 │    0 │
# └───┴──────┘
# ┌───┬─────┬─────┐
# │ E │ src │ tgt │
# ├───┼─────┼─────┤
# │ 1 │   1 │   1 │
# └───┴─────┴─────┘

# %%
to_graphviz(g_singleVertex)
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0.05", :margin => "0", :shape => "point", :width => "0.05"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:arrowsize => "0.5"))

# %%
g_reciprocalPair = @acset ReflexiveGraph begin
    V = 2
    E = 4
    src = [1,2,1,2]
    tgt = [2,1,1,2]
end
# Out:
# ReflexiveGraph {V:2, E:4}
# ┌───┬──────┐
# │ V │ refl │
# ├───┼──────┤
# │ 1 │    0 │
# │ 2 │    0 │
# └───┴──────┘
# ┌───┬─────┬─────┐
# │ E │ src │ tgt │
# ├───┼─────┼─────┤
# │ 1 │   1 │   2 │
# │ 2 │   2 │   1 │
# │ 3 │   1 │   1 │
# │ 4 │   2 │   2 │
# └───┴─────┴─────┘

# %%
to_graphviz(g_reciprocalPair)
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0.05", :margin => "0", :shape => "point", :width => "0.05"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:arrowsize => "0.5"))

# %%
T
# Out:
# ACSetLimit(Multispan{ReflexiveGraph, ACSetTransformation, Any, Vector{ACSetTransformation}, Vector{Any}}(ReflexiveGraph:
#   V = 1:1
#   E = 1:1
#   src : E → V = [1]
#   tgt : E → V = [1]
#   refl : V → E = [1], ACSetTransformation[], Any[]), (V = TerminalLimit{FinSetInt, FinFunction}(FinSet(1)), E = TerminalLimit{FinSetInt, FinFunction}(FinSet(1))), FreeDiagram(EmptyDiagram{ACSet, StaticArraysCore.SVector{0, ACSet}}(ACSet[]), Dict{Symbol, Type}(:Ob => ACSet, :FSet => FinSet, :Hom => Union{}, :V => Int64, :E => Int64)))

# %%
homomorphisms(apex(T), g_reciprocalPair, cat=𝒞)
# Out:
# Any[]

# %%
homomorphisms(g_singleVertex, g_reciprocalPair, cat=𝒞)
# Out:
# BoundsError: attempt to access 1-element Vector{Int64} at index [0]
#
# Stacktrace:
#   [1] throw_boundserror(A::Vector{Int64}, I::Tuple{Int64})
#     @ Base ./essentials.jl:14
#   [2] getindex
#     @ ./essentials.jl:916 [inlined]
#   [3] macro expansion
#     @ ~/.julia/packages/Catlab/gfcLO/src/categorical_algebra/pointwise/homsearch/HomSearch.jl:409 [inlined]
#   [4] macro expansion
#     @ ~/.julia/packages/CompTime/Ppb3B/src/CompTime.jl:137 [inlined]
#   [5] comptime(::typeof(Catlab.CategoricalAlgebra.Pointwise.HomSearch._assign_elem!), 2686::Type{Val{TypeLevelBasicSchema{Symbol, Tuple{:V, :E}, Tuple{(:src, :E, :V), (:tgt, :E, :V), (:refl, :V, :E)}, Tuple{}, Tuple{}, Tuple{(nothing, :V, :V, ((:refl, :src), ())), (nothing, :V, :V, ((:refl, :tgt), ()))}}}}, state::Catlab.CategoricalAlgebra.Pointwise.HomSearch.BacktrackingState{ReflexiveGraph, ReflexiveGraph, @NamedTuple{V::Vector{Int64}, E::Vector{Int64}}, @NamedTuple{V::Nothing, E::Nothing}, @NamedTuple{}, @NamedTuple{V::Vector{Union{Nothing, Set{Int64}}}, E::Vector{Union{Nothing, Set{Int64}}}}, @NamedTuple{V::Nothing, E::Nothing}, @NamedTuple{V::Nothing, E::Nothing}}, depth::Int64, 2687::Type{Val{:E}}, x::Int64, y::Int64)
#     @ Catlab.CategoricalAlgebra.Pointwise.HomSearch ~/.julia/packages/CompTime/Ppb3B/src/CompTime.jl:137
#   [6] _assign_elem!(2686::Type{Val{TypeLevelBasicSchema{Symbol, Tuple{:V, :E}, Tuple{(:src, :E, :V), (:tgt, :E, :V), (:refl, :V, :E)}, Tuple{}, Tuple{}, Tuple{(nothing, :V, :V, ((:refl, :src), ())), (nothing, :V, :V, ((:refl, :tgt), ()))}}}}, state::Catlab.CategoricalAlgebra.Pointwise.HomSearch.BacktrackingState{ReflexiveGraph, ReflexiveGraph, @NamedTuple{V::Vector{Int64}, E::Vector{Int64}}, @NamedTuple{V::Nothing, E::Nothing}, @NamedTuple{}, @NamedTuple{V::Vector{Union{Nothing, Set{Int64}}}, E::Vector{Union{Nothing, Set{Int64}}}}, @NamedTuple{V::Nothing, E::Nothing}, @NamedTuple{V::Nothing, E::Nothing}}, depth::Int64, 2687::Type{Val{:E}}, x::Int64, y::Int64)
#     @ Catlab.CategoricalAlgebra.Pointwise.HomSearch ./none:0
#   [7] assign_elem!(state::Catlab.CategoricalAlgebra.Pointwise.HomSearch.BacktrackingState{ReflexiveGraph, ReflexiveGraph, @NamedTuple{V::Vector{Int64}, E::Vector{Int64}}, @NamedTuple{V::Nothing, E::Nothing}, @NamedTuple{}, @NamedTuple{V::Vector{Union{Nothing, Set{Int64}}}, E::Vector{Union{Nothing, Set{Int64}}}}, @NamedTuple{V::Nothing, E::Nothing}, @NamedTuple{V::Nothing, E::Nothing}}, depth::Int64, c::Symbol, x::Int64, y::Int64)
#     @ Catlab.CategoricalAlgebra.Pointwise.HomSearch ~/.julia/packages/Catlab/gfcLO/src/categorical_algebra/pointwise/homsearch/HomSearch.jl:402
#   [8] macro expansion
#     @ ~/.julia/packages/Catlab/gfcLO/src/categorical_algebra/pointwise/homsearch/HomSearch.jl:468 [inlined]
#   [9] macro expansion
#     @ ~/.julia/packages/CompTime/Ppb3B/src/CompTime.jl:137 [inlined]
#  [10] comptime(::typeof(Catlab.CategoricalAlgebra.Pointwise.HomSearch._assign_elem!), 2686::Type{Val{TypeLevelBasicSchema{Symbol, Tuple{:V, :E}, Tuple{(:src, :E, :V), (:tgt, :E, :V), (:refl, :V, :E)}, Tuple{}, Tuple{}, Tuple{(nothing, :V, :V, ((:refl, :src), ())), (nothing, :V, :V, ((:refl, :tgt), ()))}}}}, state::Catlab.CategoricalAlgebra.Pointwise.HomSearch.BacktrackingState{ReflexiveGraph, ReflexiveGraph, @NamedTuple{V::Vector{Int64}, E::Vector{Int64}}, @NamedTuple{V::Nothing, E::Nothing}, @NamedTuple{}, @NamedTuple{V::Vector{Union{Nothing, Set{Int64}}}, E::Vector{Union{Nothing, Set{Int64}}}}, @NamedTuple{V::Nothing, E::Nothing}, @NamedTuple{V::Nothing, E::Nothing}}, depth::Int64, 2687::Type{Val{:V}}, x::Int64, y::Int64)
#     @ Catlab.CategoricalAlgebra.Pointwise.HomSearch ~/.julia/packages/CompTime/Ppb3B/src/CompTime.jl:137
#  [11] _assign_elem!(2686::Type{Val{TypeLevelBasicSchema{Symbol, Tuple{:V, :E}, Tuple{(:src, :E, :V), (:tgt, :E, :V), (:refl, :V, :E)}, Tuple{}, Tuple{}, Tuple{(nothing, :V, :V, ((:refl, :src), ())), (nothing, :V, :V, ((:refl, :tgt), ()))}}}}, state::Catlab.CategoricalAlgebra.Pointwise.HomSearch.BacktrackingState{ReflexiveGraph, ReflexiveGraph, @NamedTuple{V::Vector{Int64}, E::Vector{Int64}}, @NamedTuple{V::Nothing, E::Nothing}, @NamedTuple{}, @NamedTuple{V::Vector{Union{Nothing, Set{Int64}}}, E::Vector{Union{Nothing, Set{Int64}}}}, @NamedTuple{V::Nothing, E::Nothing}, @NamedTuple{V::Nothing, E::Nothing}}, depth::Int64, 2687::Type{Val{:V}}, x::Int64, y::Int64)
#     @ Catlab.CategoricalAlgebra.Pointwise.HomSearch ./none:0
#  [12] assign_elem!(state::Catlab.CategoricalAlgebra.Pointwise.HomSearch.BacktrackingState{ReflexiveGraph, ReflexiveGraph, @NamedTuple{V::Vector{Int64}, E::Vector{Int64}}, @NamedTuple{V::Nothing, E::Nothing}, @NamedTuple{}, @NamedTuple{V::Vector{Union{Nothing, Set{Int64}}}, E::Vector{Union{Nothing, Set{Int64}}}}, @NamedTuple{V::Nothing, E::Nothing}, @NamedTuple{V::Nothing, E::Nothing}}, depth::Int64, c::Symbol, x::Int64, y::Int64)
#     @ Catlab.CategoricalAlgebra.Pointwise.HomSearch ~/.julia/packages/Catlab/gfcLO/src/categorical_algebra/pointwise/homsearch/HomSearch.jl:402
#  [13] can_assign_elem
#     @ ~/.julia/packages/Catlab/gfcLO/src/categorical_algebra/pointwise/homsearch/HomSearch.jl:392 [inlined]
#  [14] #54
#     @ ./none:0 [inlined]
#  [15] MappingRF
#     @ ./reduce.jl:100 [inlined]
#  [16] _foldl_impl(op::Base.MappingRF{Catlab.CategoricalAlgebra.Pointwise.HomSearch.var"#54#55"{Catlab.CategoricalAlgebra.Pointwise.HomSearch.BacktrackingState{ReflexiveGraph, ReflexiveGraph, @NamedTuple{V::Vector{Int64}, E::Vector{Int64}}, @NamedTuple{V::Nothing, E::Nothing}, @NamedTuple{}, @NamedTuple{V::Vector{Union{Nothing, Set{Int64}}}, E::Vector{Union{Nothing, Set{Int64}}}}, @NamedTuple{V::Nothing, E::Nothing}, @NamedTuple{V::Nothing, E::Nothing}}, Int64, Int64, Symbol}, Base.MappingRF{Base.var"#361#362"{typeof(identity)}, Base.BottomRF{typeof(Base.add_sum)}}}, init::Int64, itr::UnitRange{Int64})
#     @ Base ./reduce.jl:58
#  [17] foldl_impl
#     @ ./reduce.jl:48 [inlined]
#  [18] mapfoldl_impl
#     @ ./reduce.jl:44 [inlined]
#  [19] mapfoldl
#     @ ./reduce.jl:175 [inlined]
#  [20] mapreduce
#     @ ./reduce.jl:307 [inlined]
#  [21] sum
#     @ ./reduce.jl:532 [inlined]
#  [22] _simple_count
#     @ ./reduce.jl:1377 [inlined]
#  [23] count
#     @ ./reduce.jl:1375 [inlined]
#  [24] count
#     @ ./reduce.jl:1373 [inlined]
#  [25] find_mrv_elem
#     @ ~/.julia/packages/Catlab/gfcLO/src/categorical_algebra/pointwise/homsearch/HomSearch.jl:375 [inlined]
#  [26] backtracking_search(f::Catlab.CategoricalAlgebra.Pointwise.HomSearch.var"#5#6"{ACSetCategory, Nothing, Nothing, Nothing, Vector{Any}}, state::Catlab.CategoricalAlgebra.Pointwise.HomSearch.BacktrackingState{ReflexiveGraph, ReflexiveGraph, @NamedTuple{V::Vector{Int64}, E::Vector{Int64}}, @NamedTuple{V::Nothing, E::Nothing}, @NamedTuple{}, @NamedTuple{V::Vector{Union{Nothing, Set{Int64}}}, E::Vector{Union{Nothing, Set{Int64}}}}, @NamedTuple{V::Nothing, E::Nothing}, @NamedTuple{V::Nothing, E::Nothing}}, depth::Int64; random::Bool)
#     @ Catlab.CategoricalAlgebra.Pointwise.HomSearch ~/.julia/packages/Catlab/gfcLO/src/categorical_algebra/pointwise/homsearch/HomSearch.jl:340
#  [27] backtracking_search(f::Catlab.CategoricalAlgebra.Pointwise.HomSearch.var"#5#6"{ACSetCategory, Nothing, Nothing, Nothing, Vector{Any}}, X::ReflexiveGraph, Y::ReflexiveGraph; monic::Bool, epic::Bool, iso::Bool, random::Bool, predicates::@NamedTuple{}, type_components::@NamedTuple{}, initial::@NamedTuple{}, error_failures::Bool, no_bind::Bool, cat::ACSetCategory)
#     @ Catlab.CategoricalAlgebra.Pointwise.HomSearch ~/.julia/packages/Catlab/gfcLO/src/categorical_algebra/pointwise/homsearch/HomSearch.jl:330
#  [28] backtracking_search
#     @ ~/.julia/packages/Catlab/gfcLO/src/categorical_algebra/pointwise/homsearch/HomSearch.jl:219 [inlined]
#  [29] #homomorphisms#4
#     @ ~/.julia/packages/Catlab/gfcLO/src/categorical_algebra/pointwise/homsearch/HomSearch.jl:129 [inlined]
#  [30] homomorphisms
#     @ ~/.julia/packages/Catlab/gfcLO/src/categorical_algebra/pointwise/homsearch/HomSearch.jl:121 [inlined]
#  [31] #homomorphisms#3
#     @ ~/.julia/packages/Catlab/gfcLO/src/categorical_algebra/pointwise/homsearch/HomSearch.jl:107 [inlined]
#  [32] top-level scope
#     @ In[36]:1

# %%
to_graphviz(g_reciprocalPair)
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0.05", :margin => "0", :shape => "point", :width => "0.05"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:arrowsize => "0.5"))

# %%
to_graphviz(g_connectedPair)
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0.05", :margin => "0", :shape => "point", :width => "0.05"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:arrowsize => "0.5"))

# %%
homomorphisms(g_singleVertex, g_connectedPair)
# Out:
# BoundsError: attempt to access 1-element Vector{Int64} at index [0]
#
# Stacktrace:
#   [1] throw_boundserror(A::Vector{Int64}, I::Tuple{Int64})
#     @ Base ./essentials.jl:14
#   [2] getindex
#     @ ./essentials.jl:916 [inlined]
#   [3] macro expansion
#     @ ~/.julia/packages/Catlab/gfcLO/src/categorical_algebra/pointwise/homsearch/HomSearch.jl:409 [inlined]
#   [4] macro expansion
#     @ ~/.julia/packages/CompTime/Ppb3B/src/CompTime.jl:137 [inlined]
#   [5] comptime(::typeof(Catlab.CategoricalAlgebra.Pointwise.HomSearch._assign_elem!), 2686::Type{Val{TypeLevelBasicSchema{Symbol, Tuple{:V, :E}, Tuple{(:src, :E, :V), (:tgt, :E, :V), (:refl, :V, :E)}, Tuple{}, Tuple{}, Tuple{(nothing, :V, :V, ((:refl, :src), ())), (nothing, :V, :V, ((:refl, :tgt), ()))}}}}, state::Catlab.CategoricalAlgebra.Pointwise.HomSearch.BacktrackingState{ReflexiveGraph, ReflexiveGraph, @NamedTuple{V::Vector{Int64}, E::Vector{Int64}}, @NamedTuple{V::Nothing, E::Nothing}, @NamedTuple{}, @NamedTuple{V::Vector{Union{Nothing, Set{Int64}}}, E::Vector{Union{Nothing, Set{Int64}}}}, @NamedTuple{V::Nothing, E::Nothing}, @NamedTuple{V::Nothing, E::Nothing}}, depth::Int64, 2687::Type{Val{:E}}, x::Int64, y::Int64)
#     @ Catlab.CategoricalAlgebra.Pointwise.HomSearch ~/.julia/packages/CompTime/Ppb3B/src/CompTime.jl:137
#   [6] _assign_elem!(2686::Type{Val{TypeLevelBasicSchema{Symbol, Tuple{:V, :E}, Tuple{(:src, :E, :V), (:tgt, :E, :V), (:refl, :V, :E)}, Tuple{}, Tuple{}, Tuple{(nothing, :V, :V, ((:refl, :src), ())), (nothing, :V, :V, ((:refl, :tgt), ()))}}}}, state::Catlab.CategoricalAlgebra.Pointwise.HomSearch.BacktrackingState{ReflexiveGraph, ReflexiveGraph, @NamedTuple{V::Vector{Int64}, E::Vector{Int64}}, @NamedTuple{V::Nothing, E::Nothing}, @NamedTuple{}, @NamedTuple{V::Vector{Union{Nothing, Set{Int64}}}, E::Vector{Union{Nothing, Set{Int64}}}}, @NamedTuple{V::Nothing, E::Nothing}, @NamedTuple{V::Nothing, E::Nothing}}, depth::Int64, 2687::Type{Val{:E}}, x::Int64, y::Int64)
#     @ Catlab.CategoricalAlgebra.Pointwise.HomSearch ./none:0
#   [7] assign_elem!(state::Catlab.CategoricalAlgebra.Pointwise.HomSearch.BacktrackingState{ReflexiveGraph, ReflexiveGraph, @NamedTuple{V::Vector{Int64}, E::Vector{Int64}}, @NamedTuple{V::Nothing, E::Nothing}, @NamedTuple{}, @NamedTuple{V::Vector{Union{Nothing, Set{Int64}}}, E::Vector{Union{Nothing, Set{Int64}}}}, @NamedTuple{V::Nothing, E::Nothing}, @NamedTuple{V::Nothing, E::Nothing}}, depth::Int64, c::Symbol, x::Int64, y::Int64)
#     @ Catlab.CategoricalAlgebra.Pointwise.HomSearch ~/.julia/packages/Catlab/gfcLO/src/categorical_algebra/pointwise/homsearch/HomSearch.jl:402
#   [8] macro expansion
#     @ ~/.julia/packages/Catlab/gfcLO/src/categorical_algebra/pointwise/homsearch/HomSearch.jl:468 [inlined]
#   [9] macro expansion
#     @ ~/.julia/packages/CompTime/Ppb3B/src/CompTime.jl:137 [inlined]
#  [10] comptime(::typeof(Catlab.CategoricalAlgebra.Pointwise.HomSearch._assign_elem!), 2686::Type{Val{TypeLevelBasicSchema{Symbol, Tuple{:V, :E}, Tuple{(:src, :E, :V), (:tgt, :E, :V), (:refl, :V, :E)}, Tuple{}, Tuple{}, Tuple{(nothing, :V, :V, ((:refl, :src), ())), (nothing, :V, :V, ((:refl, :tgt), ()))}}}}, state::Catlab.CategoricalAlgebra.Pointwise.HomSearch.BacktrackingState{ReflexiveGraph, ReflexiveGraph, @NamedTuple{V::Vector{Int64}, E::Vector{Int64}}, @NamedTuple{V::Nothing, E::Nothing}, @NamedTuple{}, @NamedTuple{V::Vector{Union{Nothing, Set{Int64}}}, E::Vector{Union{Nothing, Set{Int64}}}}, @NamedTuple{V::Nothing, E::Nothing}, @NamedTuple{V::Nothing, E::Nothing}}, depth::Int64, 2687::Type{Val{:V}}, x::Int64, y::Int64)
#     @ Catlab.CategoricalAlgebra.Pointwise.HomSearch ~/.julia/packages/CompTime/Ppb3B/src/CompTime.jl:137
#  [11] _assign_elem!(2686::Type{Val{TypeLevelBasicSchema{Symbol, Tuple{:V, :E}, Tuple{(:src, :E, :V), (:tgt, :E, :V), (:refl, :V, :E)}, Tuple{}, Tuple{}, Tuple{(nothing, :V, :V, ((:refl, :src), ())), (nothing, :V, :V, ((:refl, :tgt), ()))}}}}, state::Catlab.CategoricalAlgebra.Pointwise.HomSearch.BacktrackingState{ReflexiveGraph, ReflexiveGraph, @NamedTuple{V::Vector{Int64}, E::Vector{Int64}}, @NamedTuple{V::Nothing, E::Nothing}, @NamedTuple{}, @NamedTuple{V::Vector{Union{Nothing, Set{Int64}}}, E::Vector{Union{Nothing, Set{Int64}}}}, @NamedTuple{V::Nothing, E::Nothing}, @NamedTuple{V::Nothing, E::Nothing}}, depth::Int64, 2687::Type{Val{:V}}, x::Int64, y::Int64)
#     @ Catlab.CategoricalAlgebra.Pointwise.HomSearch ./none:0
#  [12] assign_elem!(state::Catlab.CategoricalAlgebra.Pointwise.HomSearch.BacktrackingState{ReflexiveGraph, ReflexiveGraph, @NamedTuple{V::Vector{Int64}, E::Vector{Int64}}, @NamedTuple{V::Nothing, E::Nothing}, @NamedTuple{}, @NamedTuple{V::Vector{Union{Nothing, Set{Int64}}}, E::Vector{Union{Nothing, Set{Int64}}}}, @NamedTuple{V::Nothing, E::Nothing}, @NamedTuple{V::Nothing, E::Nothing}}, depth::Int64, c::Symbol, x::Int64, y::Int64)
#     @ Catlab.CategoricalAlgebra.Pointwise.HomSearch ~/.julia/packages/Catlab/gfcLO/src/categorical_algebra/pointwise/homsearch/HomSearch.jl:402
#  [13] can_assign_elem
#     @ ~/.julia/packages/Catlab/gfcLO/src/categorical_algebra/pointwise/homsearch/HomSearch.jl:392 [inlined]
#  [14] #54
#     @ ./none:0 [inlined]
#  [15] MappingRF
#     @ ./reduce.jl:100 [inlined]
#  [16] _foldl_impl(op::Base.MappingRF{Catlab.CategoricalAlgebra.Pointwise.HomSearch.var"#54#55"{Catlab.CategoricalAlgebra.Pointwise.HomSearch.BacktrackingState{ReflexiveGraph, ReflexiveGraph, @NamedTuple{V::Vector{Int64}, E::Vector{Int64}}, @NamedTuple{V::Nothing, E::Nothing}, @NamedTuple{}, @NamedTuple{V::Vector{Union{Nothing, Set{Int64}}}, E::Vector{Union{Nothing, Set{Int64}}}}, @NamedTuple{V::Nothing, E::Nothing}, @NamedTuple{V::Nothing, E::Nothing}}, Int64, Int64, Symbol}, Base.MappingRF{Base.var"#361#362"{typeof(identity)}, Base.BottomRF{typeof(Base.add_sum)}}}, init::Int64, itr::UnitRange{Int64})
#     @ Base ./reduce.jl:58
#  [17] foldl_impl
#     @ ./reduce.jl:48 [inlined]
#  [18] mapfoldl_impl
#     @ ./reduce.jl:44 [inlined]
#  [19] mapfoldl
#     @ ./reduce.jl:175 [inlined]
#  [20] mapreduce
#     @ ./reduce.jl:307 [inlined]
#  [21] sum
#     @ ./reduce.jl:532 [inlined]
#  [22] _simple_count
#     @ ./reduce.jl:1377 [inlined]
#  [23] count
#     @ ./reduce.jl:1375 [inlined]
#  [24] count
#     @ ./reduce.jl:1373 [inlined]
#  [25] find_mrv_elem
#     @ ~/.julia/packages/Catlab/gfcLO/src/categorical_algebra/pointwise/homsearch/HomSearch.jl:375 [inlined]
#  [26] backtracking_search(f::Catlab.CategoricalAlgebra.Pointwise.HomSearch.var"#5#6"{ACSetCategory, Nothing, Nothing, Nothing, Vector{Any}}, state::Catlab.CategoricalAlgebra.Pointwise.HomSearch.BacktrackingState{ReflexiveGraph, ReflexiveGraph, @NamedTuple{V::Vector{Int64}, E::Vector{Int64}}, @NamedTuple{V::Nothing, E::Nothing}, @NamedTuple{}, @NamedTuple{V::Vector{Union{Nothing, Set{Int64}}}, E::Vector{Union{Nothing, Set{Int64}}}}, @NamedTuple{V::Nothing, E::Nothing}, @NamedTuple{V::Nothing, E::Nothing}}, depth::Int64; random::Bool)
#     @ Catlab.CategoricalAlgebra.Pointwise.HomSearch ~/.julia/packages/Catlab/gfcLO/src/categorical_algebra/pointwise/homsearch/HomSearch.jl:340
#  [27] backtracking_search(f::Catlab.CategoricalAlgebra.Pointwise.HomSearch.var"#5#6"{ACSetCategory, Nothing, Nothing, Nothing, Vector{Any}}, X::ReflexiveGraph, Y::ReflexiveGraph; monic::Bool, epic::Bool, iso::Bool, random::Bool, predicates::@NamedTuple{}, type_components::@NamedTuple{}, initial::@NamedTuple{}, error_failures::Bool, no_bind::Bool, cat::ACSetCategory)
#     @ Catlab.CategoricalAlgebra.Pointwise.HomSearch ~/.julia/packages/Catlab/gfcLO/src/categorical_algebra/pointwise/homsearch/HomSearch.jl:330
#  [28] backtracking_search
#     @ ~/.julia/packages/Catlab/gfcLO/src/categorical_algebra/pointwise/homsearch/HomSearch.jl:219 [inlined]
#  [29] #homomorphisms#4
#     @ ~/.julia/packages/Catlab/gfcLO/src/categorical_algebra/pointwise/homsearch/HomSearch.jl:129 [inlined]
#  [30] homomorphisms
#     @ ~/.julia/packages/Catlab/gfcLO/src/categorical_algebra/pointwise/homsearch/HomSearch.jl:121 [inlined]
#  [31] homomorphisms(X::ReflexiveGraph, Y::ReflexiveGraph)
#     @ Catlab.CategoricalAlgebra.Pointwise.HomSearch ~/.julia/packages/Catlab/gfcLO/src/categorical_algebra/pointwise/homsearch/HomSearch.jl:107
#  [32] top-level scope
#     @ In[40]:1

# %%
# Ok, now take the pushout with a single vertex mapped to one vertex of the pair with reciprocal (but no self) loops (on the one hand) and to the proximal end  of the connected pair (on the other)

# %%
to_graphviz(apex(pushout[C](homomorphisms(g_singleVertex, g_reciprocalPair)[1], homomorphisms(g_singleVertex, g_connectedPair)[1])))
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0.05", :margin => "0", :shape => "point", :width => "0.05"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:arrowsize => "0.5"))

# %%
# Ok, now take the pushout with a single vertex mapped to the MIDDLE vertex of the two end-to-end arrows (on the one hand) and to the distal end  of the connected pair (on the other)

# %%
homomorphisms(g_singleVertex, g_connectedPair)
# Out:
# 2-element Vector{Any}:
#  ACSetTransformation((V = FinFunction([1], FinSet(2)), E = FinFunction(Int64[], FinSet(1))), )
#  ACSetTransformation((V = FinFunction([2], FinSet(2)), E = FinFunction(Int64[], FinSet(1))), )

# %%
homomorphisms(g_singleVertex, g_endToEnd)
# Out:
# 3-element Vector{Any}:
#  ACSetTransformation((V = FinFunction([1], FinSet(3)), E = FinFunction(Int64[], FinSet(2))), )
#  ACSetTransformation((V = FinFunction([2], FinSet(3)), E = FinFunction(Int64[], FinSet(2))), )
#  ACSetTransformation((V = FinFunction([3], FinSet(3)), E = FinFunction(Int64[], FinSet(2))), )

# %%
# Students to fill in the code here to take the pushout (per the above), and to then visualize the result of that pushout, as part of Problem 1 of the take-home exercise.

# %% [markdown]
# ## As a more elaborated example, we now take pushouts of g_A and g_endtoEnd at different points mapped (via homomorphism) from a vertex

# %%
homomorphisms(g_singleVertex, g_A)
# Out:
# 3-element Vector{Any}:
#  ACSetTransformation((V = FinFunction([1], FinSet(3)), E = FinFunction(Int64[], FinSet(3))), )
#  ACSetTransformation((V = FinFunction([2], FinSet(3)), E = FinFunction(Int64[], FinSet(3))), )
#  ACSetTransformation((V = FinFunction([3], FinSet(3)), E = FinFunction(Int64[], FinSet(3))), )

# %%
homomorphisms(g_singleVertex, g_endToEnd)
# Out:
# 3-element Vector{Any}:
#  ACSetTransformation((V = FinFunction([1], FinSet(3)), E = FinFunction(Int64[], FinSet(2))), )
#  ACSetTransformation((V = FinFunction([2], FinSet(3)), E = FinFunction(Int64[], FinSet(2))), )
#  ACSetTransformation((V = FinFunction([3], FinSet(3)), E = FinFunction(Int64[], FinSet(2))), )

# %% [markdown]
# ### Reminder of g_A and g_endToEnd

# %%
to_graphviz(g_A)
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n3", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0.05", :margin => "0", :shape => "point", :width => "0.05"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:arrowsize => "0.5"))

# %%
to_graphviz(g_endToEnd)
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0.05", :margin => "0", :shape => "point", :width => "0.05"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:arrowsize => "0.5"))

# %% [markdown]
# ### Join at the start of each of the graphs

# %%
to_graphviz(apex(pushout[C](homomorphisms(g_singleVertex, g_A)[1], homomorphisms(g_singleVertex, g_endToEnd)[1])))
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n4", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n5", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n3", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n4", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n4", "", ""), Catlab.Graphics.Graphviz.NodeID("n5", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0.05", :margin => "0", :shape => "point", :width => "0.05"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:arrowsize => "0.5"))

# %% [markdown]
# ### Join at the start of g_A, but the mid-point of the end-to-end graph

# %%
to_graphviz(apex(pushout[C](homomorphisms(g_singleVertex, g_A)[1], homomorphisms(g_singleVertex, g_endToEnd)[2])))
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n4", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n5", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n3", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n4", "", ""), Catlab.Graphics.Graphviz.NodeID("n1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n5", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0.05", :margin => "0", :shape => "point", :width => "0.05"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:arrowsize => "0.5"))

# %% [markdown]
# ### Join at the start of g_A, but the endpoint of the end-to-end graph

# %%
to_graphviz(apex(pushout[C](homomorphisms(g_singleVertex, g_A)[1], homomorphisms(g_singleVertex, g_endToEnd)[3])))
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n4", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n5", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n3", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n4", "", ""), Catlab.Graphics.Graphviz.NodeID("n5", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n5", "", ""), Catlab.Graphics.Graphviz.NodeID("n1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0.05", :margin => "0", :shape => "point", :width => "0.05"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:arrowsize => "0.5"))

# %% [markdown]
# ### Join at the mid-point of g_A, but the start of the end-to-end graph

# %%
to_graphviz(apex(pushout[C](homomorphisms(g_singleVertex, g_A)[2], homomorphisms(g_singleVertex, g_endToEnd)[1])))
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n4", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n5", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n3", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n4", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n4", "", ""), Catlab.Graphics.Graphviz.NodeID("n5", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0.05", :margin => "0", :shape => "point", :width => "0.05"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:arrowsize => "0.5"))

# %% [markdown]
# ### Join at the mid-point of g_A, and the mid-point of the end-to-end graph

# %%
to_graphviz(apex(pushout[C](homomorphisms(g_singleVertex, g_A)[2], homomorphisms(g_singleVertex, g_endToEnd)[2])))
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n4", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n5", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n3", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n4", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n5", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0.05", :margin => "0", :shape => "point", :width => "0.05"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:arrowsize => "0.5"))

# %% [markdown]
# ### Join at the mid-point of g_A, and the endpoint of the end-to-end graph

# %%
to_graphviz(apex(pushout[C](homomorphisms(g_singleVertex, g_A)[2], homomorphisms(g_singleVertex, g_endToEnd)[3])))
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n4", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n5", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n3", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n4", "", ""), Catlab.Graphics.Graphviz.NodeID("n5", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n5", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0.05", :margin => "0", :shape => "point", :width => "0.05"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:arrowsize => "0.5"))

# %% [markdown]
# ### Join at the endpoint of g_A, and the start of the end-to-end graph

# %%
to_graphviz(apex(pushout[C](homomorphisms(g_singleVertex, g_A)[3], homomorphisms(g_singleVertex, g_endToEnd)[1])))
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n4", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n5", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n3", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n3", "", ""), Catlab.Graphics.Graphviz.NodeID("n4", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n4", "", ""), Catlab.Graphics.Graphviz.NodeID("n5", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0.05", :margin => "0", :shape => "point", :width => "0.05"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:arrowsize => "0.5"))

# %% [markdown]
# ### Join at the endpoint of g_A, and the mid-point of the end-to-end graph

# %%
to_graphviz(apex(pushout[C](homomorphisms(g_singleVertex, g_A)[3], homomorphisms(g_singleVertex, g_endToEnd)[2])))
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n4", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n5", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n3", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n4", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n3", "", ""), Catlab.Graphics.Graphviz.NodeID("n5", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0.05", :margin => "0", :shape => "point", :width => "0.05"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:arrowsize => "0.5"))

# %%
### Join at the endpoint of g_A, and the end-point of the end-to-end graph

# %%
to_graphviz(apex(pushout[C](homomorphisms(g_singleVertex, g_A)[3], homomorphisms(g_singleVertex, g_endToEnd)[3])))
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n4", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n5", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n3", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n4", "", ""), Catlab.Graphics.Graphviz.NodeID("n5", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n5", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0.05", :margin => "0", :shape => "point", :width => "0.05"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:arrowsize => "0.5"))

# %% [markdown]
# ### Now map from a connected pair, rather than from simply a vertex

# %%
to_graphviz(g_connectedPair)
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0.05", :margin => "0", :shape => "point", :width => "0.05"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:arrowsize => "0.5"))

# %%
to_graphviz(g_A)
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n3", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0.05", :margin => "0", :shape => "point", :width => "0.05"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:arrowsize => "0.5"))

# %%
homomorphisms(g_connectedPair, g_A)
# Out:
# 3-element Vector{Any}:
#  ACSetTransformation((V = FinFunction([1, 2], FinSet(3)), E = FinFunction([1], FinSet(3))), )
#  ACSetTransformation((V = FinFunction([2, 3], FinSet(3)), E = FinFunction([2], FinSet(3))), )
#  ACSetTransformation((V = FinFunction([3, 3], FinSet(3)), E = FinFunction([3], FinSet(3))), )

# %%
to_graphviz(g_endToEnd)
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0.05", :margin => "0", :shape => "point", :width => "0.05"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:arrowsize => "0.5"))

# %%
homomorphisms(g_connectedPair, g_endToEnd)
# Out:
# 2-element Vector{Any}:
#  ACSetTransformation((V = FinFunction([1, 2], FinSet(3)), E = FinFunction([1], FinSet(2))), )
#  ACSetTransformation((V = FinFunction([2, 3], FinSet(3)), E = FinFunction([2], FinSet(2))), )

# %% [markdown]
# # Ok, here we are "gluing graphs around a shared edge" -- we are identifying an edge (g_connectedPair) to hold in common between these graphs!

# %%
to_graphviz(apex(pushout[C](homomorphisms(g_connectedPair, g_A)[1], homomorphisms(g_connectedPair, g_endToEnd)[1])))
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n4", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n3", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n4", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0.05", :margin => "0", :shape => "point", :width => "0.05"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:arrowsize => "0.5"))

# %%
to_graphviz(apex(pushout[C](homomorphisms(g_connectedPair, g_A)[1], homomorphisms(g_connectedPair, g_endToEnd)[2])))
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n4", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n3", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n4", "", ""), Catlab.Graphics.Graphviz.NodeID("n1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0.05", :margin => "0", :shape => "point", :width => "0.05"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:arrowsize => "0.5"))

# %%
to_graphviz(apex(pushout[C](homomorphisms(g_connectedPair, g_A)[2], homomorphisms(g_connectedPair, g_endToEnd)[1])))
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n4", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n3", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n3", "", ""), Catlab.Graphics.Graphviz.NodeID("n4", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0.05", :margin => "0", :shape => "point", :width => "0.05"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:arrowsize => "0.5"))

# %%
to_graphviz(apex(pushout[C](homomorphisms(g_connectedPair, g_A)[3], homomorphisms(g_connectedPair, g_endToEnd)[1])))
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n4", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n3", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n3", "", ""), Catlab.Graphics.Graphviz.NodeID("n4", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0.05", :margin => "0", :shape => "point", :width => "0.05"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:arrowsize => "0.5"))

# %%
to_graphviz(apex(pushout[C](homomorphisms(g_connectedPair, g_A)[1], homomorphisms(g_connectedPair, g_endToEnd)[2])))
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n4", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n3", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n4", "", ""), Catlab.Graphics.Graphviz.NodeID("n1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0.05", :margin => "0", :shape => "point", :width => "0.05"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:arrowsize => "0.5"))

# %%
to_graphviz(apex(pushout[C](homomorphisms(g_connectedPair, g_A)[2], homomorphisms(g_connectedPair, g_endToEnd)[2])))
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n4", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n3", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n4", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0.05", :margin => "0", :shape => "point", :width => "0.05"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:arrowsize => "0.5"))

# %%
to_graphviz(apex(pushout[C](homomorphisms(g_connectedPair, g_A)[3], homomorphisms(g_connectedPair, g_endToEnd)[2])))
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n4", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n3", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n4", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0.05", :margin => "0", :shape => "point", :width => "0.05"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:arrowsize => "0.5"))

# %%
## define some structures

# %%
g_reciprocalPairWithSelfLoops = @acset Graph begin
    V = 2
    E = 4
    src = [1,2,1,2]
    tgt = [2,1,1,2]
end
# Out:
# Graph {V:2, E:4}
# ┌───┬─────┬─────┐
# │ E │ src │ tgt │
# ├───┼─────┼─────┤
# │ 1 │   1 │   2 │
# │ 2 │   2 │   1 │
# │ 3 │   1 │   1 │
# │ 4 │   2 │   2 │
# └───┴─────┴─────┘

# %%
to_graphviz(g_reciprocalPairWithSelfLoops)
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0.05", :margin => "0", :shape => "point", :width => "0.05"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:arrowsize => "0.5"))

# %%
to_graphviz(apex(product[C](g_reciprocalPairWithSelfLoops,g_reciprocalPairWithSelfLoops)))
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n4", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n4", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n4", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n3", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n4", "", ""), Catlab.Graphics.Graphviz.NodeID("n1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n3", "", ""), Catlab.Graphics.Graphviz.NodeID("n1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n4", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n3", "", ""), Catlab.Graphics.Graphviz.NodeID("n4", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n4", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollec ...

# %%
g_discretePairWithSelfLoops = @acset Graph begin
    V = 2
    E = 2
    src = [1,2]
    tgt = [1,2]
end
# Out:
# Graph {V:2, E:2}
# ┌───┬─────┬─────┐
# │ E │ src │ tgt │
# ├───┼─────┼─────┤
# │ 1 │   1 │   1 │
# │ 2 │   2 │   2 │
# └───┴─────┴─────┘

# %% [markdown]
# ## Now with multiplication by an arrow with reciprocal loops on both ends, rather than a discrete pair with reciprocal loops.  As a result, we can have directed connections going one direction between the two duplicates of "g_reciprocalPairWithSelfLoops"

# %%
g_connectedPairWithSelfLoops = @acset Graph begin
    V = 2
    E = 3
    src = [1,2,1]
    tgt = [1,2,2]
end
# Out:
# Graph {V:2, E:3}
# ┌───┬─────┬─────┐
# │ E │ src │ tgt │
# ├───┼─────┼─────┤
# │ 1 │   1 │   1 │
# │ 2 │   2 │   2 │
# │ 3 │   1 │   2 │
# └───┴─────┴─────┘

# %%
to_graphviz(apex(product[C](g_connectedPairWithSelfLoops,g_reciprocalPairWithSelfLoops)))
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n4", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n4", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n4", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n3", "", ""), Catlab.Graphics.Graphviz.NodeID("n1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n4", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n3", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n3", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n4", "", ""), Catlab.Graphics.Graphviz.NodeID("n4", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n3", "", ""), Catlab.Graphics.Graphviz.NodeID("n4", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0.05", :margin => "0", :shape => "point", :width => "0.05"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:arrowsize => "0.5"))

# %% [markdown]
# ## Now with multiplication by an arrow with a reciprocal loop on the proximal end only, rather than a discrete pair with reciprocal loops.  The result is that no connections are allowed within the distal side.

# %%
g_connectedPairWithProximalSelfLoop = @acset Graph begin
    V = 2
    E = 2
    src = [1,1]
    tgt = [1,2]
end
# Out:
# Graph {V:2, E:2}
# ┌───┬─────┬─────┐
# │ E │ src │ tgt │
# ├───┼─────┼─────┤
# │ 1 │   1 │   1 │
# │ 2 │   1 │   2 │
# └───┴─────┴─────┘

# %% [markdown]
# ## Now with multiplication by an arrow with a reciprocal loop on the distal end only.  The result is that no connections are allowed within the proximal side.

# %%
g_connectedPairWithDistalSelfLoop = @acset Graph begin
    V = 2
    E = 2
    src = [1,2]
    tgt = [2,2]
end
# Out:
# Graph {V:2, E:2}
# ┌───┬─────┬─────┐
# │ E │ src │ tgt │
# ├───┼─────┼─────┤
# │ 1 │   1 │   2 │
# │ 2 │   2 │   2 │
# └───┴─────┴─────┘

# %% [markdown]
# # We now explore pullbacks of graphs

# %%
## Introduce a structure for the take-home exercise

# %%
g_connectedPairWithSelfLoops = @acset Graph begin
    V = 2
    E = 3
    src = [1,2,1]
    tgt = [1,2,2]
end
# Out:
# Graph {V:2, E:3}
# ┌───┬─────┬─────┐
# │ E │ src │ tgt │
# ├───┼─────┼─────┤
# │ 1 │   1 │   1 │
# │ 2 │   2 │   2 │
# │ 3 │   1 │   2 │
# └───┴─────┴─────┘

# %%
to_graphviz(g_connectedPairWithSelfLoops)
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0.05", :margin => "0", :shape => "point", :width => "0.05"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:arrowsize => "0.5"))

# %%
## For a take-home exercise, we consider the pullback of 1) a pair of end-to-end edges 2) a connected pair, fibered around (i.e., taking the pullback over) maps down to g_connectedPairWithSelfLoops, where for 1), the source and target vertices for the first edge map down to the first vertex of g_connectedPairWithSelfLoops, and where, for 2) [the connected edge], the source vertex maps to  first vertex of g_connectedPairWithSelfLoops, and the target vertex maps to the second vertex of g_connectedPairWithSelfLoops.

# %%
homomorphisms(g_connectedPair, g_connectedPairWithSelfLoops)
# Out:
# 3-element Vector{Any}:
#  ACSetTransformation((V = FinFunction([1, 1], FinSet(2)), E = FinFunction([1], FinSet(3))), )
#  ACSetTransformation((V = FinFunction([1, 2], FinSet(2)), E = FinFunction([3], FinSet(3))), )
#  ACSetTransformation((V = FinFunction([2, 2], FinSet(2)), E = FinFunction([2], FinSet(3))), )

# %%
homomorphisms(g_endToEnd, g_connectedPairWithSelfLoops)
# Out:
# 4-element Vector{Any}:
#  ACSetTransformation((V = FinFunction([1, 1, 1], FinSet(2)), E = FinFunction([1, 1], FinSet(3))), )
#  ACSetTransformation((V = FinFunction([1, 1, 2], FinSet(2)), E = FinFunction([1, 3], FinSet(3))), )
#  ACSetTransformation((V = FinFunction([1, 2, 2], FinSet(2)), E = FinFunction([3, 2], FinSet(3))), )
#  ACSetTransformation((V = FinFunction([2, 2, 2], FinSet(2)), E = FinFunction([2, 2], FinSet(3))), )

# %%
# The student should fill in the code here to perform the pullback, and then to visualize the result of that pullback, as part of the take-home exercise Problem 2.

# %% [markdown]
# # A related example, but with added flexibility afforded by a self-loop on one of the graphs

# %%
g_connectedPairWithProximalSelfLoop = @acset Graph begin
    V = 2
    E = 2
    src = [1,1]
    tgt = [1,2]
end
# Out:
# Graph {V:2, E:2}
# ┌───┬─────┬─────┐
# │ E │ src │ tgt │
# ├───┼─────┼─────┤
# │ 1 │   1 │   1 │
# │ 2 │   1 │   2 │
# └───┴─────┴─────┘

# %%
g_endToEndWithProximalLoop = @acset Graph begin
    V = 3
    E = 2
    src = [1, 2]
    tgt = [2, 3]
end
# Out:
# Graph {V:3, E:2}
# ┌───┬─────┬─────┐
# │ E │ src │ tgt │
# ├───┼─────┼─────┤
# │ 1 │   1 │   2 │
# │ 2 │   2 │   3 │
# └───┴─────┴─────┘

# %%
homomorphisms(g_connectedPairWithProximalSelfLoop, g_connectedPairWithSelfLoops)
# Out:
# 3-element Vector{Any}:
#  ACSetTransformation((V = FinFunction([1, 1], FinSet(2)), E = FinFunction([1, 1], FinSet(3))), )
#  ACSetTransformation((V = FinFunction([1, 2], FinSet(2)), E = FinFunction([1, 3], FinSet(3))), )
#  ACSetTransformation((V = FinFunction([2, 2], FinSet(2)), E = FinFunction([2, 2], FinSet(3))), )

# %%
homomorphisms(g_endToEnd, g_connectedPairWithSelfLoops)
# Out:
# 4-element Vector{Any}:
#  ACSetTransformation((V = FinFunction([1, 1, 1], FinSet(2)), E = FinFunction([1, 1], FinSet(3))), )
#  ACSetTransformation((V = FinFunction([1, 1, 2], FinSet(2)), E = FinFunction([1, 3], FinSet(3))), )
#  ACSetTransformation((V = FinFunction([1, 2, 2], FinSet(2)), E = FinFunction([3, 2], FinSet(3))), )
#  ACSetTransformation((V = FinFunction([2, 2, 2], FinSet(2)), E = FinFunction([2, 2], FinSet(3))), )

# %%
to_graphviz(apex(pullback[C](homomorphisms(g_connectedPairWithProximalSelfLoop, g_connectedPairWithSelfLoops)[2], homomorphisms(g_endToEnd, g_connectedPairWithSelfLoops)[2])))
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Node("n3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0.05", :margin => "0", :shape => "point", :width => "0.05"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:arrowsize => "0.5"))

# %% [markdown]
# # Now we have another example

# %%
to_graphviz(g_connectedPairWithSelfLoops; node_labels=true, edge_labels=true)
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "1")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "2")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "1")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "2")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "3"))], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0.05", :margin => "0", :shape => "circle", :width => "0.05"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:arrowsize => "0.5"))

# %%
g_endToEndWithReciprocalDistalConnections = @acset Graph begin
    V = 3
    E = 3
    src = [1, 2, 3]
    tgt = [2, 3, 2]
end
# Out:
# Graph {V:3, E:3}
# ┌───┬─────┬─────┐
# │ E │ src │ tgt │
# ├───┼─────┼─────┤
# │ 1 │   1 │   2 │
# │ 2 │   2 │   3 │
# │ 3 │   3 │   2 │
# └───┴─────┴─────┘

# %%
to_graphviz(g_endToEndWithReciprocalDistalConnections; node_labels=true, edge_labels=true)
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "1")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "2")), Catlab.Graphics.Graphviz.Node("n3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "3")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "1")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "2")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n3", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "3"))], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0.05", :margin => "0", :shape => "circle", :width => "0.05"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:arrowsize => "0.5"))

# %%
g_B = @acset Graph begin
    V = 4
    E = 4
    src = [1, 2, 3, 4]
    tgt = [3, 1, 2, 3]
end
# Out:
# Graph {V:4, E:4}
# ┌───┬─────┬─────┐
# │ E │ src │ tgt │
# ├───┼─────┼─────┤
# │ 1 │   1 │   3 │
# │ 2 │   2 │   1 │
# │ 3 │   3 │   2 │
# │ 4 │   4 │   3 │
# └───┴─────┴─────┘

# %%
to_graphviz(g_B; node_labels=true, edge_labels=true)
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "1")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "2")), Catlab.Graphics.Graphviz.Node("n3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "3")), Catlab.Graphics.Graphviz.Node("n4", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "4")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "1")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "2")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n3", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "3")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n4", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "4"))], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0.05", :margin => "0", :shape => "circle", :width => "0.05"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:arrowsize => "0.5"))

# %%
g_endToEndWithReciprocalDistalConnections_to_type=homomorphisms(g_endToEndWithReciprocalDistalConnections, g_connectedPairWithSelfLoops)[2]
# Out:
# ACSetTransformation((V = FinFunction([1, 2, 2], FinSet(2)), E = FinFunction([3, 2, 2], FinSet(3))), )

# %%
to_graphviz(g_endToEndWithReciprocalDistalConnections_to_type; node_labels=true, edge_labels=true, draw_codom=true)
# Out:
# Catlab.Graphics.Graphviz.Graph("hom_graph", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Subgraph("cluster_dom", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("dom_1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "1")), Catlab.Graphics.Graphviz.Node("dom_2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "2")), Catlab.Graphics.Graphviz.Node("dom_3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "3")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("dom_1", "", ""), Catlab.Graphics.Graphviz.NodeID("dom_2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "1")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("dom_2", "", ""), Catlab.Graphics.Graphviz.NodeID("dom_3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "2")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("dom_3", "", ""), Catlab.Graphics.Graphviz.NodeID("dom_2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "3"))], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Subgraph("cluster_cod", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("cod_1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "1")), Catlab.Graphics.Graphviz.Node("cod_2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "2")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("cod_1", "", ""), Catlab.Graphics.Graphviz.NodeID("cod_1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "1")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("cod_2", "", ""), Catlab.Graphics.Graphviz.NodeID("cod_2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "2")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("cod_1", "", ""), Catlab.Graphics.Graphviz.NodeID("cod_2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "3"))], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("\"dom_1\"", "", ""), Catlab.Graphics.Graphviz.NodeID("\"cod_1\"", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:constraint => "false", :style => "dotted")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("\"dom_2\"", "", ""), Catlab.Graphics.Graphviz.NodeID("\"cod_2\"", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:constraint => "false", :style => "dotted")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("\"dom_3\"", "", ""), Catlab.Graphics.Graphviz.NodeID("\"cod_2\"", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:constraint => "false", :style => "dotted"))], Ordere ...

# %%
to_graphviz(g_endToEndWithReciprocalDistalConnections_to_type; node_labels=true, edge_labels=true, draw_codom=false)
# Out:
# Catlab.Graphics.Graphviz.Graph("hom_graph", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("dom_1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:color => "#C721DD", :label => "1")), Catlab.Graphics.Graphviz.Node("dom_2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:color => "#D14A00", :label => "2")), Catlab.Graphics.Graphviz.Node("dom_3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:color => "#D14A00", :label => "3")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("dom_1", "", ""), Catlab.Graphics.Graphviz.NodeID("dom_2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:color => "#00BFFF", :label => "1")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("dom_2", "", ""), Catlab.Graphics.Graphviz.NodeID("dom_3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:color => "#00BB20", :label => "2")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("dom_3", "", ""), Catlab.Graphics.Graphviz.NodeID("dom_2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:color => "#00BB20", :label => "3"))], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0.05", :margin => "0", :shape => "circle", :width => "0.05"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:arrowsize => "0.5"))

# %%
g_B_to_type=homomorphisms(g_B, g_connectedPairWithSelfLoops)[2]
# Out:
# ACSetTransformation((V = FinFunction([2, 2, 2, 1], FinSet(2)), E = FinFunction([2, 2, 2, 3], FinSet(3))), )

# %%
to_graphviz(g_B_to_type; node_labels=true, edge_labels=true, draw_codom=true)
# Out:
# Catlab.Graphics.Graphviz.Graph("hom_graph", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Subgraph("cluster_dom", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("dom_1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "1")), Catlab.Graphics.Graphviz.Node("dom_2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "2")), Catlab.Graphics.Graphviz.Node("dom_3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "3")), Catlab.Graphics.Graphviz.Node("dom_4", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "4")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("dom_1", "", ""), Catlab.Graphics.Graphviz.NodeID("dom_3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "1")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("dom_2", "", ""), Catlab.Graphics.Graphviz.NodeID("dom_1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "2")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("dom_3", "", ""), Catlab.Graphics.Graphviz.NodeID("dom_2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "3")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("dom_4", "", ""), Catlab.Graphics.Graphviz.NodeID("dom_3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "4"))], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Subgraph("cluster_cod", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("cod_1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "1")), Catlab.Graphics.Graphviz.Node("cod_2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "2")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("cod_1", "", ""), Catlab.Graphics.Graphviz.NodeID("cod_1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "1")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("cod_2", "", ""), Catlab.Graphics.Graphviz.NodeID("cod_2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "2")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("cod_1", "", ""), Catlab.Graphics.Graphviz.NodeID("cod_2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "3"))], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}()), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("\"dom_1\"", "", ""), Catlab.Graphics.Graphviz.NodeID("\"cod_2\"", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:constraint => "false", :style => "dotted")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("\"dom_2\"", "", ""), Catlab.Graphics.Graphviz.NodeID("\"cod_2\"", "", "")], OrderedCollections.OrderedDict{Sym ...

# %%
to_graphviz(g_B_to_type; node_labels=true, edge_labels=true, draw_codom=false)
# Out:
# Catlab.Graphics.Graphviz.Graph("hom_graph", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("dom_1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:color => "#D14A00", :label => "1")), Catlab.Graphics.Graphviz.Node("dom_2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:color => "#D14A00", :label => "2")), Catlab.Graphics.Graphviz.Node("dom_3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:color => "#D14A00", :label => "3")), Catlab.Graphics.Graphviz.Node("dom_4", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:color => "#C721DD", :label => "4")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("dom_1", "", ""), Catlab.Graphics.Graphviz.NodeID("dom_3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:color => "#00BB20", :label => "1")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("dom_2", "", ""), Catlab.Graphics.Graphviz.NodeID("dom_1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:color => "#00BB20", :label => "2")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("dom_3", "", ""), Catlab.Graphics.Graphviz.NodeID("dom_2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:color => "#00BB20", :label => "3")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("dom_4", "", ""), Catlab.Graphics.Graphviz.NodeID("dom_3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:color => "#00BFFF", :label => "4"))], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0.05", :margin => "0", :shape => "circle", :width => "0.05"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:arrowsize => "0.5"))

# %%
pb_gA_gB_apex = apex(pullback[C](g_endToEndWithReciprocalDistalConnections_to_type, g_B_to_type))
# Out:
# Graph {V:7, E:7}
# ┌───┬─────┬─────┐
# │ E │ src │ tgt │
# ├───┼─────┼─────┤
# │ 1 │   1 │   6 │
# │ 2 │   2 │   5 │
# │ 3 │   3 │   2 │
# │ 4 │   4 │   1 │
# │ 5 │   5 │   4 │
# │ 6 │   6 │   3 │
# │ 7 │   7 │   5 │
# └───┴─────┴─────┘

# %%
to_graphviz(pb_gA_gB_apex; node_labels=true, edge_labels=true)
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "dot", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "1")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "2")), Catlab.Graphics.Graphviz.Node("n3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "3")), Catlab.Graphics.Graphviz.Node("n4", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "4")), Catlab.Graphics.Graphviz.Node("n5", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "5")), Catlab.Graphics.Graphviz.Node("n6", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "6")), Catlab.Graphics.Graphviz.Node("n7", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "7")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n6", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "1")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n5", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "2")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n3", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "3")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n4", "", ""), Catlab.Graphics.Graphviz.NodeID("n1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "4")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n5", "", ""), Catlab.Graphics.Graphviz.NodeID("n4", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "5")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n6", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "6")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n7", "", ""), Catlab.Graphics.Graphviz.NodeID("n5", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "7"))], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0.05", :margin => "0", :shape => "circle", :width => "0.05"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:arrowsize => "0.5"))

# %% [markdown]
# # Now we turn to Discrete Dynamical Systems

# %%
 #2. define the schema of DDS
@present SchDDS(FreeSchema) begin
    State::Ob
    next::Hom(State,State)
    end;

# %%
to_graphviz(SchDDS)
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "neato", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "State")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "next"))], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:margin => "0", :shape => "ellipse"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())

# %%
@acset_type DDSInstance(SchDDS, index=[:next])
# Out:
# DDSInstance

# %%
const S=ACSetCategory(CSetCat(DDSInstance()))
#const 𝒞 = ACSetCategory(CSetCat(Graph()))
# Out:
# ACSetCategory(CSetCat(DDSInstance))

# %%
dds_reciprocalPair = @acset DDSInstance begin
    State = 2
    next = [2, 1]
end
# Out:
# DDSInstance {State:2}
# ┌───────┬──────┐
# │ State │ next │
# ├───────┼──────┤
# │     1 │    2 │
# │     2 │    1 │
# └───────┴──────┘

# %%
# define a discrete dynamical system cycling amongst 4 states.
dds_cycle3 = @acset DDSInstance begin
    State = 3
    next = [2, 3, 1]
end
# Out:
# DDSInstance {State:3}
# ┌───────┬──────┐
# │ State │ next │
# ├───────┼──────┤
# │     1 │    2 │
# │     2 │    3 │
# │     3 │    1 │
# └───────┴──────┘

# %%
# define the same graph
dds_cycle2 = @acset DDSInstance begin
    State = 2
    next = [2, 1]
end
# Out:
# DDSInstance {State:2}
# ┌───────┬──────┐
# │ State │ next │
# ├───────┼──────┤
# │     1 │    2 │
# │     2 │    1 │
# └───────┴──────┘

# %%
to_graphviz(elements(dds_cycle2))
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "neato", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "State")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "State")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "next")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "next"))], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0", :margin => "0.025", :shape => "box", :width => "0"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())

# %%
dds_twoStateThenTrapped = @acset DDSInstance begin
    State = 3
    next = [2, 3, 3]
end
# Out:
# DDSInstance {State:3}
# ┌───────┬──────┐
# │ State │ next │
# ├───────┼──────┤
# │     1 │    2 │
# │     2 │    3 │
# │     3 │    3 │
# └───────┴──────┘

# %%
to_graphviz(elements(dds_twoStateThenTrapped))
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "neato", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "State")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "State")), Catlab.Graphics.Graphviz.Node("n3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "State")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "next")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "next")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n3", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "next"))], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0", :margin => "0.025", :shape => "box", :width => "0"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())

# %%
dds_threeStateThenTrapped = @acset DDSInstance begin
    State = 4
    next = [2, 3, 4, 4]
end
# Out:
# DDSInstance {State:4}
# ┌───────┬──────┐
# │ State │ next │
# ├───────┼──────┤
# │     1 │    2 │
# │     2 │    3 │
# │     3 │    4 │
# │     4 │    4 │
# └───────┴──────┘

# %%
to_graphviz(elements(dds_threeStateThenTrapped))
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "neato", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "State")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "State")), Catlab.Graphics.Graphviz.Node("n3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "State")), Catlab.Graphics.Graphviz.Node("n4", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "State")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "next")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "next")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n3", "", ""), Catlab.Graphics.Graphviz.NodeID("n4", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "next")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n4", "", ""), Catlab.Graphics.Graphviz.NodeID("n4", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "next"))], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0", :margin => "0.025", :shape => "box", :width => "0"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())

# %%
dds_singleState = terminal[S]()
# Out:
# ACSetLimit(Multispan{DDSInstance, ACSetTransformation, Any, Vector{ACSetTransformation}, Vector{Any}}(DDSInstance:
#   State = 1:1
#   next : State → State = [1], ACSetTransformation[], Any[]), (State = TerminalLimit{FinSetInt, FinFunction}(FinSet(1)),), FreeDiagram(EmptyDiagram{ACSet, StaticArraysCore.SVector{0, ACSet}}(ACSet[])))

# %%
to_graphviz(elements(apex(dds_singleState)))
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "neato", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "State")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n1", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "next"))], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0", :margin => "0.025", :shape => "box", :width => "0"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())

# %%
typeof(ob(dds_singleState))
typeof(dds_twoStateThenTrapped)
# Out:
# DDSInstance

# %%
to_graphviz(elements(apex(pushout[S](homomorphisms(ob(dds_singleState), dds_threeStateThenTrapped)[1], homomorphisms(ob(dds_singleState), dds_twoStateThenTrapped)[1]))))
# Out:
# Catlab.Graphics.Graphviz.Graph("G", true, "neato", Catlab.Graphics.Graphviz.Statement[Catlab.Graphics.Graphviz.Node("n1", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "State")), Catlab.Graphics.Graphviz.Node("n2", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "State")), Catlab.Graphics.Graphviz.Node("n3", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "State")), Catlab.Graphics.Graphviz.Node("n4", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "State")), Catlab.Graphics.Graphviz.Node("n5", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "State")), Catlab.Graphics.Graphviz.Node("n6", OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "State")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n1", "", ""), Catlab.Graphics.Graphviz.NodeID("n2", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "next")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n2", "", ""), Catlab.Graphics.Graphviz.NodeID("n3", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "next")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n3", "", ""), Catlab.Graphics.Graphviz.NodeID("n4", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "next")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n4", "", ""), Catlab.Graphics.Graphviz.NodeID("n4", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "next")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n5", "", ""), Catlab.Graphics.Graphviz.NodeID("n6", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "next")), Catlab.Graphics.Graphviz.Edge(Catlab.Graphics.Graphviz.NodeID[Catlab.Graphics.Graphviz.NodeID("n6", "", ""), Catlab.Graphics.Graphviz.NodeID("n4", "", "")], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:label => "next"))], OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}(:height => "0", :margin => "0.025", :shape => "box", :width => "0"), OrderedCollections.OrderedDict{Symbol, Union{String, Catlab.Graphics.Graphviz.Html}}())

# %%
#to_graphviz(elements(apex(pushout[S](homomorphism(dds_singleState, dds_twoStateThenTrapped)[1], homomorphism(dds_singleState, dds_threeStateThenTrapped)[1]))))

# %%
homomorphism(ob(dds_singleState), dds_twoStateThenTrapped)
# Out:
# ACSetTransformation((State = FinFunction([3], FinSet(3)),), )
